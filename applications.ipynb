# %% [markdown]
# # About
# `applications` is the Notebook where we apply our knowledge of coding.

# %% [markdown]
# # Making Games With `tkinter`
# Just now, we made this game of _bounce_:

# %%
from tkinter import *
import random
import time
class Ball:
    def __init__(self, canvas, paddle, color):
        self.canvas = canvas
        self.paddle = paddle
        self.id = canvas.create_oval(10, 10, 25, 25, fill=color)
        self.canvas.move(self.id, 245, 100)
        starts = [-3, -2, -1, 1, 2, 3]
        self.x = starts[random.randrange(5)]
        self.y = -2
        self.canvas_height = self.canvas.winfo_height()
        self.canvas_width = self.canvas.winfo_width()
        self.hit_bottom = False
    def hit_paddle(self, pos):
        paddle_pos = self.canvas.coords(self.paddle.id)
        if pos[2] >= paddle_pos[0] and pos[0] <= paddle_pos[2]:
            if pos[3] >= paddle_pos[1] and pos[3] <= paddle_pos[3]:
                return True
        return False
    def draw(self):
        self.canvas.move(self.id, self.x, self.y)
        pos = self.canvas.coords(self.id)
        if pos[1] <= 0:
            self.y = 2
        if pos[3] >= self.canvas_height:
            self.y = -2
        if pos[3] >= self.canvas_height:
            self.hit_bottom = True
        if self.hit_paddle(pos) == True:
            self.y = -2
        if pos[0] <= 0:
            self.x = 2
        if pos[2] >= self.canvas_width:
            self.x = -2
class Paddle:
    def __init__(self, canvas, color):
        self.canvas = canvas
        self.id = canvas.create_rectangle(0, 0, 100, 10, fill=color)
        self.canvas.move(self.id, 200, 300)
        self.x = 0
        self.canvas_width = self.canvas.winfo_width()
        self.canvas.bind_all('<KeyPress-Left>', self.turn_left)
        self.canvas.bind_all('<KeyPress-Right>', self.turn_right)
    def draw(self):
        self.canvas.move(self.id, self.x, 0)
        pos = self.canvas.coords(self.id)
        if pos[0] <= 0:
            self.x = 0
        elif pos[2] >= self.canvas_width:
            self.x = 0    
    def turn_left(self, evt):
        self.x = -1
    def turn_right(self, evt):
        self.x = 1
tk = Tk()
tk.title('Game')
tk.resizable(0, 0)
tk.wm_attributes("-topmost", 1)
canvas = Canvas(tk, width=500, height=400, bd=0, highlightthickness=0)
canvas.pack()
tk.update()
paddle = Paddle(canvas, 'blue')
ball = Ball(canvas, paddle, 'red')
while ball.hit_bottom == False:
    ball.draw()
    paddle.draw()
    tk.update_idletasks()
    tk.update()
    time.sleep(0.0083333333333333)

# %% [markdown]
# ## Challenge 1: Delaying the Start of the Game

# %%
from tkinter import *
import random
import time
class Ball:
    def __init__(self, canvas, paddle, color):
        self.canvas = canvas
        self.paddle = paddle
        self.id = canvas.create_oval(10, 10, 25, 25, fill=color)
        self.canvas.move(self.id, 245, 100)
        starts = [-3, -2, -1, 1, 2, 3]
        self.x = starts[random.randrange(5)]
        self.y = -2
        self.canvas_height = self.canvas.winfo_height()
        self.canvas_width = self.canvas.winfo_width()
        self.hit_bottom = False
    def hit_paddle(self, pos):
        paddle_pos = self.canvas.coords(self.paddle.id)
        if pos[2] >= paddle_pos[0] and pos[0] <= paddle_pos[2]:
            if pos[3] >= paddle_pos[1] and pos[3] <= paddle_pos[3]:
                return True
        return False
    def draw(self):
        self.canvas.move(self.id, self.x, self.y)
        pos = self.canvas.coords(self.id)
        if pos[1] <= 0:
            self.y = 2
        if pos[3] >= self.canvas_height:
            self.y = -2
        if pos[3] >= self.canvas_height:
            self.hit_bottom = True
            
        if self.hit_paddle(pos) == True:
            self.y = -2
        if pos[0] <= 0:
            self.x = 2
        if pos[2] >= self.canvas_width:
            self.x = -2
class Paddle:
    def __init__(self, canvas, color):
        self.canvas = canvas
        self.id = canvas.create_rectangle(0, 0, 100, 10, fill=color)
        self.canvas.move(self.id, 200, 300)
        self.x = 0
        self.canvas_width = self.canvas.winfo_width()
        self.canvas.bind_all('<KeyPress-Left>', self.turn_left)
        self.canvas.bind_all('<KeyPress-Right>', self.turn_right)
    def draw(self):
        self.canvas.move(self.id, self.x, 0)
        pos = self.canvas.coords(self.id)
        if pos[0] <= 0:
            self.x = 0
        elif pos[2] >= self.canvas_width:
            self.x = 0    
    def turn_left(self, evt):
        self.x = -1.3
    def turn_right(self, evt):
        self.x = 1.3
tk = Tk()
tk.title('Game')
tk.resizable(0, 0)
tk.wm_attributes("-topmost", 1)
canvas = Canvas(tk, width=500, height=400, bd=0, highlightthickness=0)
canvas.pack()
tk.update()
paddle = Paddle(canvas, 'blue')
ball = Ball(canvas, paddle, 'red')

# We add this:
ball.draw()
paddle.draw()
tk.update_idletasks()
tk.update()
time.sleep(5)

while ball.hit_bottom == False:
    ball.draw()
    paddle.draw()
    tk.update_idletasks()
    tk.update()
    time.sleep(0.0083333333333333)

# %% [markdown]
# This seems to be working fine!
# ### Using Bindings

# %%
from tkinter import *
import random
import time
class Ball:
    def __init__(self, canvas, paddle, color):
        self.canvas = canvas
        self.paddle = paddle
        self.id = canvas.create_oval(10, 10, 25, 25, fill=color)
        self.canvas.move(self.id, 245, 100)
        starts = [-3, -2, -1, 1, 2, 3]
        self.x = starts[random.randrange(5)]
        self.y = -2
        self.canvas_height = self.canvas.winfo_height()
        self.canvas_width = self.canvas.winfo_width()
        self.hit_bottom = False
    def hit_paddle(self, pos):
        paddle_pos = self.canvas.coords(self.paddle.id)
        if pos[2] >= paddle_pos[0] and pos[0] <= paddle_pos[2]:
            if pos[3] >= paddle_pos[1] and pos[3] <= paddle_pos[3]:
                return True
        return False
    def draw(self):
        self.canvas.move(self.id, self.x, self.y)
        pos = self.canvas.coords(self.id)
        if pos[1] <= 0:
            self.y = 2
        if pos[3] >= self.canvas_height:
            self.y = -2
        if pos[3] >= self.canvas_height:
            self.hit_bottom = True
        if self.hit_paddle(pos) == True:
            self.y = -2
        if pos[0] <= 0:
            self.x = 2
        if pos[2] >= self.canvas_width:
            self.x = -2
class Paddle:
    def __init__(self, canvas, color):
        self.canvas = canvas
        self.id = canvas.create_rectangle(0, 0, 100, 10, fill=color)
        self.canvas.move(self.id, 200, 300)
        self.x = 0
        self.canvas_width = self.canvas.winfo_width()
        
        self.started = False
        
        self.canvas.bind_all('<KeyPress-Left>', self.turn_left)
        self.canvas.bind_all('<KeyPress-Right>', self.turn_right)
        
        self.canvas.bind_all('<Button-1>', self.start_game)
        
    def draw(self):
        self.canvas.move(self.id, self.x, 0)
        pos = self.canvas.coords(self.id)
        if pos[0] <= 0:
            self.x = 0
        elif pos[2] >= self.canvas_width:
            self.x = 0    
    def turn_left(self, evt):
        self.x = -1
    def turn_right(self, evt):
        self.x = 1
        
    def start_game(self, evt):
        self.started = True
        
tk = Tk()
tk.title('Game')
tk.resizable(0, 0)
tk.wm_attributes("-topmost", 1)
canvas = Canvas(tk, width=500, height=400, bd=0, highlightthickness=0)
canvas.pack()
tk.update()
paddle = Paddle(canvas, 'blue')
ball = Ball(canvas, paddle, 'red')

while 1:
    while ball.hit_bottom == False and paddle.started == True:
        ball.draw()
        paddle.draw()
        tk.update_idletasks()
        tk.update()
        time.sleep(0.0083333333333333)
    tk.update_idletasks()
    tk.update()
    time.sleep(5)
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7560/1907873907.py in <module>
#      82         tk.update()
#      83         time.sleep(0.0083333333333333)
# ---> 84     tk.update_idletasks()
#      85     tk.update()
#      86     time.sleep(5)
#
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.240.0_x64__qbz5n2kfra8p0\lib\tkinter\__init__.py in update_idletasks(self)
#    1347         will update the display of windows but not process events caused by
#    1348         the user."""
# -> 1349         self.tk.call('update', 'idletasks')
#    1350
#    1351     def bindtags(self, tagList=None):
#
# TclError: can't invoke "update" command: application has been destroyed

# %% [markdown]
# ## Challenge 2: Game Over

# %%
from tkinter import *
import random
import time
class Ball:
    def __init__(self, canvas, paddle, color):
        self.canvas = canvas
        self.paddle = paddle
        self.id = canvas.create_oval(10, 10, 25, 25, fill=color)
        self.canvas.move(self.id, 245, 100)
        starts = [-3, -2, -1, 1, 2, 3]
        self.x = starts[random.randrange(5)]
        self.y = -2
        self.canvas_height = self.canvas.winfo_height()
        self.canvas_width = self.canvas.winfo_width()
        self.hit_bottom = False
    def hit_paddle(self, pos):
        paddle_pos = self.canvas.coords(self.paddle.id)
        if pos[2] >= paddle_pos[0] and pos[0] <= paddle_pos[2]:
            if pos[3] >= paddle_pos[1] and pos[3] <= paddle_pos[3]:
                return True
        return False
    def draw(self):
        self.canvas.move(self.id, self.x, self.y)
        pos = self.canvas.coords(self.id)
        if pos[1] <= 0:
            self.y = 2
        if pos[3] >= self.canvas_height:
            self.y = -2
        if pos[3] >= self.canvas_height:
            self.hit_bottom = True
        if self.hit_paddle(pos) == True:
            self.y = -2
        if pos[0] <= 0:
            self.x = 2
        if pos[2] >= self.canvas_width:
            self.x = -2
class Paddle:
    def __init__(self, canvas, color):
        self.canvas = canvas
        self.id = canvas.create_rectangle(0, 0, 100, 10, fill=color)
        self.canvas.move(self.id, 200, 300)
        self.x = 0
        self.canvas_width = self.canvas.winfo_width()
        self.started = False
        self.canvas.bind_all('<KeyPress-Left>', self.turn_left)
        self.canvas.bind_all('<KeyPress-Right>', self.turn_right)
        self.canvas.bind_all('<Button-1>', self.start_game)
    def draw(self):
        self.canvas.move(self.id, self.x, 0)
        pos = self.canvas.coords(self.id)
        if pos[0] <= 0:
            self.x = 0
        elif pos[2] >= self.canvas_width:
            self.x = 0    
    def turn_left(self, evt):
        self.x = -1
    def turn_right(self, evt):
        self.x = 1
    def start_game(self, evt):
        self.started = True
tk = Tk()
tk.title('Game')
tk.resizable(0, 0)
tk.wm_attributes("-topmost", 1)
canvas = Canvas(tk, width=500, height=400, bd=0, highlightthickness=0)
canvas.pack()
tk.update()
paddle = Paddle(canvas, 'blue')
ball = Ball(canvas, paddle, 'red')
while 1:
    while ball.hit_bottom == False and paddle.started == True:
        ball.draw()
        paddle.draw()
        tk.update_idletasks()
        tk.update()
        time.sleep(0.0083333333333333)
    if paddle.started == False:
        tk.update_idletasks()
        tk.update()
        time.sleep(5)
    else:
        time.sleep(1)
        game_over_text = canvas.create_text(250, 200, text='GAME OVER')
        tk.update_idletasks()
        tk.update()
        time.sleep(5)
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7560/207111399.py in <module>
#      81     else:
#      82         time.sleep(1)
# ---> 83         game_over_text = canvas.create_text(250, 200, text='GAME OVER')
#      84         tk.update_idletasks()
#      85         tk.update()
#
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.240.0_x64__qbz5n2kfra8p0\lib\tkinter\__init__.py in create_text(self, *args, **kw)
#    2837     def create_text(self, *args, **kw):
#    2838         """Create text with coordinates x1,y1."""
# -> 2839         return self._create('text', args, kw)
#    2840
#    2841     def create_window(self, *args, **kw):
#
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.240.0_x64__qbz5n2kfra8p0\lib\tkinter\__init__.py in _create(self, itemType, args, kw)
#    2803         else:
#    2804             cnf = {}
# -> 2805         return self.tk.getint(self.tk.call(
#    2806             self._w, 'create', itemType,
#    2807             *(args + self._options(cnf, kw))))
#
# TclError: invalid command name ".!canvas"

# %% [markdown]
# This was their approach:

# %%
from tkinter import *
import random
import time
class Ball:
    def __init__(self, canvas, paddle, color):
        self.canvas = canvas
        self.paddle = paddle
        self.id = canvas.create_oval(10, 10, 25, 25, fill=color)
        self.canvas.move(self.id, 245, 100)
        starts = [-3, -2, -1, 1, 2, 3]
        self.x = starts[random.randrange(5)]
        self.y = -2
        self.canvas_height = self.canvas.winfo_height()
        self.canvas_width = self.canvas.winfo_width()
        self.hit_bottom = False
    def hit_paddle(self, pos):
        paddle_pos = self.canvas.coords(self.paddle.id)
        if pos[2] >= paddle_pos[0] and pos[0] <= paddle_pos[2]:
            if pos[3] >= paddle_pos[1] and pos[3] <= paddle_pos[3]:
                return True
        return False
    def draw(self):
        self.canvas.move(self.id, self.x, self.y)
        pos = self.canvas.coords(self.id)
        if pos[1] <= 0:
            self.y = 2
        if pos[3] >= self.canvas_height:
            self.y = -2
        if pos[3] >= self.canvas_height:
            self.hit_bottom = True
        if self.hit_paddle(pos) == True:
            self.y = -2
        if pos[0] <= 0:
            self.x = 2
        if pos[2] >= self.canvas_width:
            self.x = -2
class Paddle:
    def __init__(self, canvas, color):
        self.canvas = canvas
        self.id = canvas.create_rectangle(0, 0, 100, 10, fill=color)
        self.canvas.move(self.id, 200, 300)
        self.x = 0
        self.canvas_width = self.canvas.winfo_width()
        self.started = False
        self.canvas.bind_all('<KeyPress-Left>', self.turn_left)
        self.canvas.bind_all('<KeyPress-Right>', self.turn_right)
        self.canvas.bind_all('<Button-1>', self.start_game)
    def draw(self):
        self.canvas.move(self.id, self.x, 0)
        pos = self.canvas.coords(self.id)
        if pos[0] <= 0:
            self.x = 0
        elif pos[2] >= self.canvas_width:
            self.x = 0    
    def turn_left(self, evt):
        self.x = -1
    def turn_right(self, evt):
        self.x = 1
    def start_game(self, evt):
        self.started = True
tk = Tk()
tk.title('Game')
tk.resizable(0, 0)
tk.wm_attributes("-topmost", 1)
canvas = Canvas(tk, width=500, height=400, bd=0, highlightthickness=0)
canvas.pack()
tk.update()
paddle = Paddle(canvas, 'blue')
ball = Ball(canvas, paddle, 'red')
game_over_text = canvas.create_text(250, 200, text='GAME OVER', state='hidden')
while 1:
    while ball.hit_bottom == False and paddle.started == True:
        ball.draw()
        paddle.draw()
        tk.update_idletasks()
        tk.update()
        time.sleep(0.0083333333333333)
    if paddle.started == False:
        tk.update_idletasks()
        tk.update()
        time.sleep(5)
    else:
        time.sleep(1)
        canvas.itemconfig(game_over_text, state='normal')
        tk.update_idletasks()
        tk.update()
        time.sleep(5)
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7560/2944666869.py in <module>
#      71 while 1:
#      72     while ball.hit_bottom == False and paddle.started == True:
# ---> 73         ball.draw()
#      74         paddle.draw()
#      75         tk.update_idletasks()
#
# ~\AppData\Local\Temp/ipykernel_7560/2944666869.py in draw(self)
#      21         return False
#      22     def draw(self):
# ---> 23         self.canvas.move(self.id, self.x, self.y)
#      24         pos = self.canvas.coords(self.id)
#      25         if pos[1] <= 0:
#
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.240.0_x64__qbz5n2kfra8p0\lib\tkinter\__init__.py in move(self, *args)
#    2947     def move(self, *args):
#    2948         """Move an item TAGORID given in ARGS."""
# -> 2949         self.tk.call((self._w, 'move') + args)
#    2950
#    2951     def moveto(self, tagOrId, x='', y=''):
#
# TclError: invalid command name ".!canvas"

# %% [markdown]
# ## Challenge 3: Acceleration
# Make the ball inherit the speed of the paddle. (I gave up!)
# More specifically, we have to speed the ball up if it is going in the same horizontal direction when it hits the paddle and slow down if it goes in the opposite direction when hitting the ball. I gave up on this too!

# %%
from tkinter import *
import random
import time
class Ball:
    def __init__(self, canvas, paddle, color):
        self.canvas = canvas
        self.paddle = paddle
        self.id = canvas.create_oval(10, 10, 25, 25, fill=color)
        self.canvas.move(self.id, 245, 100)
        starts = [-3, -2, -1, 1, 2, 3]
        self.x = starts[random.randrange(5)]
        self.y = -2
        self.canvas_height = self.canvas.winfo_height()
        self.canvas_width = self.canvas.winfo_width()
        self.hit_bottom = False
        
    # I simplified this function:
    def hit_paddle(self, pos):
        paddle_pos = self.canvas.coords(self.paddle.id)
        if pos[2] >= paddle_pos[0] and pos[0] <= paddle_pos[2] and pos[3] >= paddle_pos[1] and pos[3] <= paddle_pos[3]:

            # I add this:
            self.x += self.paddle.x
            
            return True
        else:
            return False
        
    def draw(self):
        self.canvas.move(self.id, self.x, self.y)
        pos = self.canvas.coords(self.id)
        if pos[1] <= 0:
            self.y = 2
        if pos[3] >= self.canvas_height:
            self.y = -2
        if pos[3] >= self.canvas_height:
            self.hit_bottom = True
        if self.hit_paddle(pos) == True:
            self.y = -2
        if pos[0] <= 0:
            self.x = 2
        if pos[2] >= self.canvas_width:
            self.x = -2
class Paddle:
    def __init__(self, canvas, color):
        self.canvas = canvas
        self.id = canvas.create_rectangle(0, 0, 100, 10, fill=color)
        self.canvas.move(self.id, 200, 300)
        self.x = 0
        self.canvas_width = self.canvas.winfo_width()
        self.started = False
        self.canvas.bind_all('<KeyPress-Left>', self.turn_left)
        self.canvas.bind_all('<KeyPress-Right>', self.turn_right)
        self.canvas.bind_all('<Button-1>', self.start_game)
    def draw(self):
        self.canvas.move(self.id, self.x, 0)
        pos = self.canvas.coords(self.id)
        if pos[0] <= 0:
            self.x = 0
        elif pos[2] >= self.canvas_width:
            self.x = 0    
    def turn_left(self, evt):
        self.x = -1
    def turn_right(self, evt):
        self.x = 1
    def start_game(self, evt):
        self.started = True
tk = Tk()
tk.title('Game')
tk.resizable(0, 0)
tk.wm_attributes("-topmost", 1)
canvas = Canvas(tk, width=500, height=400, bd=0, highlightthickness=0)
canvas.pack()
tk.update()
paddle = Paddle(canvas, 'blue')
ball = Ball(canvas, paddle, 'red')
game_over_text = canvas.create_text(250, 200, text='GAME OVER', state='hidden')
while 1:
    while ball.hit_bottom == False and paddle.started == True:
        ball.draw()
        paddle.draw()
        tk.update_idletasks()
        tk.update()
        time.sleep(0.0083333333333333)
    if paddle.started == False:
        tk.update_idletasks()
        tk.update()
        time.sleep(5)
    else:
        time.sleep(1)
        canvas.itemconfig(game_over_text, state='normal')
        tk.update_idletasks()
        tk.update()
        time.sleep(5)
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9864/3533640233.py in <module>
#      89     else:
#      90         time.sleep(1)
# ---> 91         canvas.itemconfig(game_over_text, state='normal')
#      92         tk.update_idletasks()
#      93         tk.update()
#
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.240.0_x64__qbz5n2kfra8p0\lib\tkinter\__init__.py in itemconfigure(self, tagOrId, cnf, **kw)
#    2930         the allowed keyword arguments call the method without arguments.
#    2931         """
# -> 2932         return self._configure(('itemconfigure', tagOrId), cnf, kw)
#    2933
#    2934     itemconfig = itemconfigure
#
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.240.0_x64__qbz5n2kfra8p0\lib\tkinter\__init__.py in _configure(self, cmd, cnf, kw)
#    1663         if isinstance(cnf, str):
#    1664             return self._getconfigure1(_flatten((self._w, cmd, '-'+cnf)))
# -> 1665         self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
#    1666     # These used to be defined in Widget:
#    1667
#
# TclError: invalid command name ".!canvas"

# %% [markdown]
# This was genius. By adding the speed of the paddle (horizontally), the ball gains another pixel per 0.0083 (Vinculum) seconds.
#
# ## Challenge 4: Score!

# %%
from tkinter import *
import random
import time
class Ball:
    
    # We alter this a bit:
    def __init__(self, canvas, paddle, score, color):
        self.canvas = canvas
        self.paddle = paddle
        self.score = score
        self.id = canvas.create_oval(10, 10, 25, 25, fill=color)
        self.canvas.move(self.id, 245, 100)
        starts = [-3, -2, -1, 1, 2, 3]
        self.x = starts[random.randrange(5)]
        self.y = -2
        self.canvas_height = self.canvas.winfo_height()
        self.canvas_width = self.canvas.winfo_width()
        self.hit_bottom = False
    def hit_paddle(self, pos):
        paddle_pos = self.canvas.coords(self.paddle.id)
        if pos[2] >= paddle_pos[0] and pos[0] <= paddle_pos[2] and pos[3] >= paddle_pos[1] and pos[3] <= paddle_pos[3]:
            self.x += self.paddle.x
            
            # Add this:
            self.score.hit()
            
            return True
        else:
            return False
    def draw(self):
        self.canvas.move(self.id, self.x, self.y)
        pos = self.canvas.coords(self.id)
        if pos[1] <= 0:
            self.y = 2
        if pos[3] >= self.canvas_height:
            self.y = -2
        if pos[3] >= self.canvas_height:
            self.hit_bottom = True
        if self.hit_paddle(pos) == True:
            self.y = -2
        if pos[0] <= 0:
            self.x = 2
        if pos[2] >= self.canvas_width:
            self.x = -2
class Paddle:
    def __init__(self, canvas, color):
        self.canvas = canvas
        self.id = canvas.create_rectangle(0, 0, 100, 10, fill=color)
        self.canvas.move(self.id, 200, 300)
        self.x = 0
        self.canvas_width = self.canvas.winfo_width()
        self.started = False
        self.canvas.bind_all('<KeyPress-Left>', self.turn_left)
        self.canvas.bind_all('<KeyPress-Right>', self.turn_right)
        self.canvas.bind_all('<Button-1>', self.start_game)
    def draw(self):
        self.canvas.move(self.id, self.x, 0)
        pos = self.canvas.coords(self.id)
        if pos[0] <= 0:
            self.x = 0
        elif pos[2] >= self.canvas_width:
            self.x = 0    
    def turn_left(self, evt):
        self.x = -1
    def turn_right(self, evt):
        self.x = 1
    def start_game(self, evt):
        self.started = True
        
# We add this:
class Score:
    def __init__(self, canvas, color):
        self.score = 0
        self.canvas = canvas
        self.id = canvas.create_text(450, 10, text=self.score, fill=color)
    def hit(self):
        self.score += 1
        self.canvas.itemconfig(self.id, text = self.score)

tk = Tk()
tk.title('Game')
tk.resizable(0, 0)
tk.wm_attributes("-topmost", 1)
canvas = Canvas(tk, width=500, height=400, bd=0, highlightthickness=0)
canvas.pack()
tk.update()

# Add this line:
score = Score(canvas, 'green')
paddle = Paddle(canvas, 'blue')

# Alter this:
ball = Ball(canvas, paddle, score, 'red')

game_over_text = canvas.create_text(250, 200, text='GAME OVER', state='hidden')
while 1:
    while ball.hit_bottom == False and paddle.started == True:
        ball.draw()
        paddle.draw()
        tk.update_idletasks()
        tk.update()
        time.sleep(0.0083333333333333)
    if paddle.started == False:
        tk.update_idletasks()
        tk.update()
        time.sleep(5)
    else:
        time.sleep(1)
        canvas.itemconfig(game_over_text, state='normal')
        tk.update_idletasks()
        tk.update()
        time.sleep(5)
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4928/957719289.py in <module>
#     107     else:
#     108         time.sleep(1)
# --> 109         canvas.itemconfig(game_over_text, state='normal')
#     110         tk.update_idletasks()
#     111         tk.update()
#
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.240.0_x64__qbz5n2kfra8p0\lib\tkinter\__init__.py in itemconfigure(self, tagOrId, cnf, **kw)
#    2930         the allowed keyword arguments call the method without arguments.
#    2931         """
# -> 2932         return self._configure(('itemconfigure', tagOrId), cnf, kw)
#    2933
#    2934     itemconfig = itemconfigure
#
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.240.0_x64__qbz5n2kfra8p0\lib\tkinter\__init__.py in _configure(self, cmd, cnf, kw)
#    1663         if isinstance(cnf, str):
#    1664             return self._getconfigure1(_flatten((self._w, cmd, '-'+cnf)))
# -> 1665         self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
#    1666     # These used to be defined in Widget:
#    1667
#
# TclError: invalid command name ".!canvas"

# %% [markdown]
# ## Our Own Challenge: Restart
# We will be working on this after coding the amazing Mr Stick Man Game!
